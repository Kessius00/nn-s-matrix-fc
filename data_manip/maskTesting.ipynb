# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np
import time
import random
import scipy.stats as stats
from scipy.sparse import *
from visualizingData import *
from clipping import *
from other import *
import os

# %%
# Load the data from the specified .npz file
file = np.load(".\\provided_data\\FTICR.npz", allow_pickle=True)

# # Extract the necessary components from the file
print(file.files)

selected_B = file['selected_B'][()]
shape = file['shape'][()]
mz_values = file['mz'][()]
# Out:
# ['selected_B', 'shape', 'mz']

# %%
subset = selected_B[:20,:20]

csc_ss = csc_matrix(subset)

# %%
csc_ss.nnz/np.prod(subset.shape)
# Out:
# 1.0

# %%
imp_matrix, mask = partlyDiscardedClipping(subset, .5,.2)

# %%
visualizeData(subset)

# %%
# percentage of non-zero values
100*csc_matrix(imp_matrix).nnz/np.prod(imp_matrix.shape)
# Out:
# 9.25

# %%
visualizeData(imp_matrix)

# %%
visualizeData(mask)
