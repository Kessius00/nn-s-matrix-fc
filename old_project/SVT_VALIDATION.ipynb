# %%
import numpy as np
import matplotlib.pyplot as plt
from numpy.linalg import inv, norm, svd, matrix_rank
from Helpers import *
import math
import time

# %%
def ImageRepresentation(data, sampled_data, reconstructed_data, colormap='cubehelix'):
    # Create a colormap and set NaN values to be transparent (or red if preferred)
    cmap = plt.get_cmap(colormap).copy()
    cmap.set_bad(color='none')  # Use 'none' for transparency or 'red' for red color
    
    colormaps = [cmap]*3 
    
    fig, axes = plt.subplots(1, 3, figsize=(20, 10))  # Create a figure with 1 row and 3 columns
    
    # Plot each matrix with its respective colormap
    for ax, matrix, cmap, title in zip(axes, [data, sampled_data, reconstructed_data], colormaps, ['Original Data', 'Sampled Data', 'Reconstructed Data']):
        cax = ax.imshow(matrix, aspect='auto', cmap=cmap)
        ax.set_title(f'{title} Colormap')
        fig.colorbar(cax, ax=ax)
        
    # Add overall title and show the plot
    fig.suptitle(f'Side by Side comparison of Data, Sampled Data and Reconstruction', fontsize=16)
    plt.show()

def relative_approx_error(original, approximation):
    """
    Calculate the relative approximation error between the original and approximation matrices.
    """
    error = norm(original - approximation, 'fro')
    fro_M = norm(original, 'fro')
    rel_error = 100 * (error / fro_M) ** 2
    print(f'relative error = {rel_error}%')
    return rel_error

def soft_thresholding(U, Sigma, VT, threshold):
    """
    Apply soft-thresholding to the singular values in the decomposition.
    """
    Sigma_thresholded = np.maximum(Sigma - threshold, 0)
    return (U * (Sigma_thresholded)) @ VT

def random_matrix_generation(num_rows, num_columns, rank):
    """
    Generate a random matrix of specified rank with values between 0 and 1.
    """
    A = np.random.normal(size=(num_rows, rank))
    B = np.random.normal(size=(rank, num_columns))
#     A= np.random.randn(num_rows, rank)
#     B= np.random.randn(rank, num_columns)
    M = A @ B
    return M


def projection_operator(M_sampled, X):
    """
    Compute the projection operator for matrix completion.
    """
    filled_M_sampled = np.where(M_sampled == 0, X, M_sampled)
    projection = X - filled_M_sampled
    return projection

def suggested_stop(X_k, original_sampled, tolerance):
    """
    Check the stopping condition based on the relative difference between X_k and the original sampled matrix.
    """
    rel_error = norm(projection_operator(original_sampled, X_k), 'fro') / norm(original_sampled, 'fro')
    print("Current relative in-sampling error:", rel_error)
    return rel_error <= tolerance

def k_0_finder(tau, step_size, sampled_entries):
    """
    Find the initial value of k_0.
    """
    return math.ceil(tau / (step_size * norm(sampled_entries, 2)))


def plot_metrics(em,r):
    """
    Plot error history and rank history over iterations.
    """
    fig, ax1 = plt.subplots()

    # Plot error history
    color = 'tab:red'
    ax1.set_xlabel('Iteration')
    ax1.set_ylabel('Relative in-sampling error', color=color)
    ax1.plot(range(len(em)), em, color=color, label='Relative in-sampling error')
    ax1.tick_params(axis='y', labelcolor=color)
    ax1.set_yscale('log')


    # Instantiate a second axes that shares the same x-axis
    ax2 = ax1.twinx()
    color = 'tab:blue'
    ax2.set_ylabel('Rank of X', color=color)
    ax2.plot(range(len(r)), r, color=color, label='Rank of X')
    ax2.tick_params(axis='y', labelcolor=color)

    fig.tight_layout()  # Adjust layout to avoid overlap
    plt.title('Error and Rank Convergence Over Iterations')
    ax1.legend(loc='upper left')  # Add legend for error plots
    ax2.legend(loc='upper right')  # Add legend for rank plot
    plt.show()

# %%
# Parameters for matrix generation
n = 1000    # Matrix dimensions
r = 10      # Rank
m = 120000  # Cardinality
p = m/(n*n)

# Generate a random low-rank matrix
M= random_matrix_generation(n,n,r)

# Calculate matrix characteristics
M_nuc = norm(M, 'nuc')
M_fro = norm(M, 'fro')
M_rank = matrix_rank(M)
M_shape = M.shape
print(p)

# Parameters for Singular Value Thresholding (SVT)
step_size = 1.2/p
tolerance = 1e-7
# Out:
# 0.12

# %%
M_sampled, coords, coords_TF, M_sampled_nans = sample_from_matrix_ratio(M,ratio_to_keep=p, seed=42)

# %%
def svt_algorithm(sampled_entries, step_size, tolerance, tau, max_iter=117):
    """
    Singular Value Thresholding (SVT) algorithm for matrix completion.
    """
    k = 1
    Y_0 = k_0_finder(tau, step_size, sampled_entries) * step_size * sampled_entries
    u, s, v = svd(Y_0, full_matrices=False)
    print(s[0])
    
    iterate = True
    em_sampled_arr = []
    rank_arr = []
    in_sampling_err_list = []


    while iterate:
        if k == 1:
            Y = Y_0

        # Singular Value Decomposition
        U, sigma, Vt = svd(Y, full_matrices=False)
        # Thresholding
        sigma_thresh = np.maximum(sigma - tau, 0)
        # Check for rank stopping condition
        rank = np.sum(sigma_thresh > 0)
        # Construct the approximation matrix X
        X = U[:, :rank] * sigma_thresh[:rank] @ Vt[:rank, :]

        # Calculate errors
        
        # CHECK
        error_sampled_matrix = -projection_operator(M_sampled=sampled_entries, X=X)
        in_sampling_error = (norm(projection_operator(sampled_entries, X=X), 'fro') / norm(sampled_entries, 'fro')) 

        # Update Y
        Y = Y + step_size * error_sampled_matrix

        k += 1
        print(k, norm(error_sampled_matrix, 'fro'))

        # Append results for plotting
        rank_arr.append(rank)
        em_sampled_arr.append(norm(error_sampled_matrix, 'fro'))
        in_sampling_err_list.append(in_sampling_error)

        # Check stopping conditions
        if suggested_stop(X, sampled_entries, tolerance):
            iterate = False
            print("SUGGESTED STOP")
            
        if k >= max_iter:
            print("MAX ITER STOP")
            iterate = False

    return X, em_sampled_arr, rank_arr, in_sampling_err_list

# %%
start_time = time.time()
# Run the SVT algorithm
X_opt, em_sampled_arr, rank_arr, in_sampling_err_list = svt_algorithm(M_sampled, step_size, tolerance, tau=5*(n), max_iter=118)

run_time = time.time() - start_time
print('Total runtime:',run_time)
# Out:
# 5687.864399305631
# 2 809.8001583014589
# Current relative in-sampling error: 0.7389965441185328
# 3 536.2785807407789
# Current relative in-sampling error: 0.4893898992110301
# 4 371.1534541742698
# Current relative in-sampling error: 0.33870223061914595
# 5 264.2887263610736
# Current relative in-sampling error: 0.24118105365646988
# 6 205.05226290335472
# Current relative in-sampling error: 0.18712383801838406
# 7 169.0194020570437
# Current relative in-sampling error: 0.15424145417694357
# 8 144.4460025792788
# Current relative in-sampling error: 0.1318165915671338
# 9 125.43252316498241
# Current relative in-sampling error: 0.11446552607919244
# 10 110.0362237012934
# Current relative in-sampling error: 0.10041537805286338
# 11 97.21768597532846
# Current relative in-sampling error: 0.08871760918602312
# 12 86.41195187026361
# Current relative in-sampling error: 0.07885665759389708
# 13 77.20304270604471
# Current relative in-sampling error: 0.07045291504371858
# 14 69.28847713056767
# Current relative in-sampling error: 0.0632303471687692
# 15 62.4342827671496
# Current relative in-sampling error: 0.05697543860230645
# 16 56.458815631320284
# Current relative in-sampling error: 0.051522427118419006
# 17 51.21829710816514
# Current relative in-sampling error: 0.04674010516120455
# 18 46.59776151653561
# Current relative in-sampling error: 0.042523558894588746
# 19 42.504210977847016
# Current relative in-sampling error: 0.03878792156449664
# 20 38.86170243678933
# Current relative in-sampling error: 0.03546389007824715
# 21 35.607666666585104
# Current relative in-sampling error: 0.03249436585184681
# 22 32.69014103947859
# Current relative in-sampling error: 0.02983192952887643
# 23 30.06565421386324
# Current relative in-sampling error: 0.02743691061670136
# 24 27.697592978705888
# Current relative in-sampling error: 0.025275897123306988
# 25 25.55492757850845
# Current relative in-sampling error: 0.023320572331484945
# 26 23.611207660336614
# Current relative in-sampling error: 0.02154679853366775
# 27 21.843764544312073
# Current relative in-sampling error: 0.019933889050656756
# 28 20.233072436830856
# Current relative in-sampling error: 0.01846402529616671
# 29 18.76223318300224
# Current relative in-sampling error: 0.017121786579131788
# 30 17.416557845533937
# Current relative in-sampling error: 0.015893768266588535
# 31 16.183224754122016
# Current relative in-sampling error: 0.014768269730984216
# 32 15.050998378885614
# Current relative in-sampling error: 0.013735037803474421
# 33 14.009996903883774
# Current relative in-sampling error: 0.012785054669287043
# 34 13.051499036457876
# Current relative in-sampling error: 0.011910361568388638
# 35 12.167782613275648
# Current relative in-sampling error: 0.011103911512757325
# 36 11.351989117961459
# Current relative in-sampling error: 0.010359445649702828
# 37 10.598009426289009
# Current relative in-sampling error: 0.009671388996750092
# 38 9.900387029457105
# Current relative in-sampling error: 0.009034762126437048
# 39 9.254235717687028
# Current relative in-sampling error: 0.008445106047118296
# 40 8.655169282682008
# Current relative in-sampling error: 0.00789841805178042
# 41 8.099241253924449
# Current relative in-sampling error: 0.007391096723402106
# 42 7.582893047203553
# Current relative in-sampling error: 0.006919894617034407
# 43 7.102909194600896
# Current relative in-sampling error: 0.006481877404182716
# 44 6.656378559026911
# Current relative in-sampling error: 0.006074388478489786
# 45 6.240660625351855
# Current relative in-sampling error: 0.005695018194149091
# 46 5.8533561135027785
# Current relative in-sampling error: 0.005341577048399852
# 47 5.4922812838755615
# Current relative in-sampling error: 0.0050120722335052995
# 48 5.155445407694051
# Current relative in-sampling error: 0.004704687076955837
# 49 4.8410309590017375
# Current relative in-sampling error: 0.004417762965343033
# 50 4.547376154312869
# Current relative in-sampling error: 0.004149783410629126
# 51 4.272959523369309
# Current relative in-sampling error: 0.0038993599699356884
# 52 4.0163862421733345
# Current relative in-sampling error: 0.0036652197735263983
# 53 3.776375999268676
# Current relative in-sampling error: 0.0034461944519808755
# 54 3.551752199555615
# Current relative in-sampling error: 0.003241210283957373
# 55 3.34143233789669
# Current relative in-sampling error: 0.003049279411467256
# 56 3.1444193983341946
# Current relative in-sampling error: 0.0028694919910885125
# 57 2.9597941546492863
# Current relative in-sampling error: 0.0027010091677134663
# 58 2.786708264872372
# Current relative in-sampling error: 0.0025430567728298823
# 59 2.6243780666940055
# Current relative in-sampling error: 0.002394919662420437
# 60 2.4720789929571825
# Current relative in-sampling error: 0.0022559366207277384
# 61 2.329140536861901
# Current relative in-sampling error: 0.0021254957656683727
# 62 2.1949417054690845
# Current relative in-sampling error: 0.002003030399852627
# 63 2.0689069077892768
# Current relative in-sampling error: 0.0018880152581917335
# 64 1.9505022303667576
# Current relative in-sampling error: 0.0017799631091204831
# 65 1.8392320589964446
# Current relative in-sampling error: 0.0016784216716890425
# 66 1.7346360101627885
# Current relative in-sampling error: 0.0015829708152967044
# 67 1.6362861400839543
# Current relative in-sampling error: 0.0014932200127589395
# 68 1.5437844029845218
# Current relative in-sampling error: 0.0014088060208120592
# 69 1.4567603334671297
# Current relative in-sampling error: 0.0013293907651230831
# 70 1.374868930698075
# Current relative in-sampling error: 0.00125465940946827
# 71 1.2977887246053124
# Current relative in-sampling error: 0.0011843185910100807
# 72 1.2252200064619008
# Current relative in-sampling error: 0.001118094805586802
# 73 1.1568832081446545
# Current relative in-sampling error: 0.0010557329286781899
# 74 1.0925174160333924
# Current relative in-sampling error: 0.0009969948592396215
# 75 1.0318790070053352
# Current relative in-sampling error: 0.0009416582749561957
# 76 0.9747403952810046
# Current relative in-sampling error: 0.0008895154886562058
# 77 0.9208888800403191
# Current relative in-sampling error: 0.0008403723966841263
# 78 0.8701255847502425
# Current relative in-sampling error: 0.0007940475109664946
# 79 0.8222644800544431
# Current relative in-sampling error: 0.0007503710673336885
# 80 0.7771314828858535
# Current relative in-sampling error: 0.0007091842034001759
# 81 0.7345636251799117
# Current relative in-sampling error: 0.000670338199960016
# 82 0.6944082862089694
# Current relative in-sampling error: 0.0006336937804409131
# 83 0.656522483129874
# Current relative in-sampling error: 0.0005991204634816637
# 84 0.6207722148494585
# Current relative in-sampling error: 0.0005664959641657442
# 85 0.5870318547688264
# Current relative in-sampling error: 0.0005357056398600529
# 86 0.5551835883801618
# Current relative in-sampling error: 0.0005066419769845659
# 87 0.525116892055785
# Current relative in-sampling error: 0.0004792041153726589
# 88 0.4967280497027049
# Current relative in-sampling error: 0.00045329740718621494
# 89 0.4699197042525843
# Current relative in-sampling error: 0.0004288330076203656
# 90 0.4446004412241665
# Current relative in-sampling error: 0.00040572749487648743
# 91 0.42068440184209877
# Current relative in-sampling error: 0.00038390251710737784
# 92 0.3980909234079208
# Current relative in-sampling error: 0.0003632844642318453
# 93 0.3767442048234389
# Current relative in-sampling error: 0.0003438041627025259
# 94 0.356572995340454
# Current relative in-sampling error: 0.0003253965914692937
# 95 0.33751030477650146
# Current relative in-sampling error: 0.0003080006175318353
# 96 0.3194931335812702
# Current relative in-sampling error: 0.0002915587496072907
# 97 0.302462221272483
# Current relative in-sampling error: 0.00027601690856125045
# 98 0.2863618118822221
# Current relative in-sampling error: 0.00026132421336191565
# 99 0.2711394351633172
# Current relative in-sampling error: 0.0002474327814163647
# 100 0.256745702408064
# Current relative in-sampling error: 0.00023429754224154334
# 101 0.24313411582163375
# Current relative in-sampling error: 0.0002218760635048134
# 102 0.230260890476154
# Current relative in-sampling error: 0.00021012838854520045
# 103 0.21808478795016623
# Current relative in-sampling error: 0.0001990168845583264
# 104 0.20656696082353582
# Current relative in-sampling error: 0.00018850610068766433
# 105 0.19567080726690977
# Current relative in-sampling error: 0.00017856263532774034
# 106 0.1853618350185923
# Current relative in-sampling error: 0.00016915501199397896
# 107 0.17560753409861268
# Current relative in-sampling error: 0.0001602535631658179
# 108 0.1663772576574095
# Current relative in-sampling error: 0.0001518303215532019
# 109 0.1576421104008262
# Current relative in-sampling error: 0.00014385891827696485
# 110 0.14937484407728746
# Current relative in-sampling error: 0.0001363144874939218
# 111 0.14154975954691765
# Current relative in-sampling error: 0.00012917357702842152
# 112 0.13414261499206462
# Current relative in-sampling error: 0.00012241406460833986
# 113 0.12713053985608858
# Current relative in-sampling error: 0.00011601507932849659
# 114 0.120491954131384
# Current relative in-sampling error: 0.00010995692799560315
# 115 0.11420649264121736
# Current relative in-sampling error: 0.00010422102603039986
# 116 0.10825493398766815
# Current relative in-sampling error: 9.878983262792298e-05
# 117 0.10261913386009765
# Current relative in-sampling error: 9.364678989704348e-05
# 118 0.0972819624196746
# Current relative in-sampling error: 8.87762657196791e-05
# MAX ITER STOP
# Total runtime: 41.724637269973755

# %%
general_error_relative(M, X_opt)
# Out:
# 0.00014984956106603732

# %%
plot_metrics(in_sampling_err_list, rank_arr)

# %%
# Parameters for matrix generation
n = 1000    # Matrix dimensions
r = 50      # Rank
m = .39*n*n  # Cardinality
p = m/(n*n)

# Generate a random low-rank matrix
M= random_matrix_generation(n,n,r)

# Calculate matrix characteristics
M_nuc = norm(M, 'nuc')
M_fro = norm(M, 'fro')
M_rank = matrix_rank(M)
M_shape = M.shape
print(p)

# Parameters for Singular Value Thresholding (SVT)
step_size = 1.2/p
tolerance = 1e-7
# Out:
# 0.39

# %%
M_sampled, coords, coords_TF, M_sampled_nans = sample_from_matrix_ratio(M,ratio_to_keep=p, seed=42)

# %%
start_time = time.time()
# Run the SVT algorithm
X_opt, em_sampled_arr, rank_arr, in_sampling_err_list = svt_algorithm(M_sampled, step_size, tolerance, tau=5*(n), max_iter=114)

run_time = time.time() - start_time
print('Total runtime:',run_time)
# Out:
# 6521.23250876617
# 2 3072.161515552186
# Current relative in-sampling error: 0.6989952221963773
# 3 1874.4579234467858
# Current relative in-sampling error: 0.4264870600274888
# 4 1143.6397475037218
# Current relative in-sampling error: 0.26020725647794923
# 5 937.4083832420584
# Current relative in-sampling error: 0.2132843529925076
# 6 798.7120047109357
# Current relative in-sampling error: 0.18172738392092228
# 7 688.6854825065931
# Current relative in-sampling error: 0.15669353952622228
# 8 598.9484918904925
# Current relative in-sampling error: 0.1362760818576071
# 9 524.7284998178263
# Current relative in-sampling error: 0.11938913773451403
# 10 462.702710528972
# Current relative in-sampling error: 0.10527668624184706
# 11 410.3374896126968
# Current relative in-sampling error: 0.09336226083014953
# 12 365.7313116968946
# Current relative in-sampling error: 0.0832132159033944
# 13 327.42270828213447
# Current relative in-sampling error: 0.07449703004520386
# 14 294.28285726826385
# Current relative in-sampling error: 0.06695686739238456
# 15 265.42717376699375
# Current relative in-sampling error: 0.06039146228640552
# 16 240.15515516291228
# Current relative in-sampling error: 0.05464143248813958
# 17 217.90568646827043
# Current relative in-sampling error: 0.049579110004366406
# 18 198.22474575320626
# Current relative in-sampling error: 0.04510119324819371
# 19 180.7414499363297
# Current relative in-sampling error: 0.04112329684451258
# 20 165.1501913608781
# Current relative in-sampling error: 0.03757588724475717
# 21 151.1971272370042
# Current relative in-sampling error: 0.03440120872990228
# 22 138.6698566414078
# Current relative in-sampling error: 0.03155093466418176
# 23 127.38944652078682
# Current relative in-sampling error: 0.02898435320718031
# 24 117.20421199189772
# Current relative in-sampling error: 0.026666952173216955
# 25 107.98481987608776
# Current relative in-sampling error: 0.024569304960372476
# 26 99.62040079955909
# Current relative in-sampling error: 0.02266618595398427
# 27 92.01543727253564
# Current relative in-sampling error: 0.020935862485163766
# 28 85.08725416785644
# Current relative in-sampling error: 0.019359523850571506
# 29 78.7639807609288
# Current relative in-sampling error: 0.01792081762444739
# 30 72.98288481442447
# Current relative in-sampling error: 0.016605470620323793
# 31 67.68900235801492
# Current relative in-sampling error: 0.015400977130913492
# 32 62.83400411218502
# Current relative in-sampling error: 0.01429634101057041
# 33 58.37525253491171
# Current relative in-sampling error: 0.01328186112932158
# 34 54.27501336627431
# Current relative in-sampling error: 0.012348951979125142
# 35 50.49979312145064
# Current relative in-sampling error: 0.01148999293660342
# 36 47.019779824440874
# Current relative in-sampling error: 0.010698201015678824
# 37 43.808368811607096
# Current relative in-sampling error: 0.009967522975765883
# 38 40.841758980644784
# Current relative in-sampling error: 0.009292543458098582
# 39 38.098607650573584
# Current relative in-sampling error: 0.008668406457561758
# 40 35.559734406157936
# Current relative in-sampling error: 0.008090747939731592
# 41 33.207866057287454
# Current relative in-sampling error: 0.007555637812619713
# 42 31.02741624975803
# Current relative in-sampling error: 0.00705952978249613
# 43 29.004294394624683
# Current relative in-sampling error: 0.0065992178804361555
# 44 27.12573949713772
# Current relative in-sampling error: 0.0061717986541586015
# 45 25.380175208339743
# Current relative in-sampling error: 0.005774638188561435
# 46 23.757083027641354
# Current relative in-sampling error: 0.005405343256068749
# 47 22.24689108052579
# Current relative in-sampling error: 0.005061736010717428
# 48 20.840876303373907
# Current relative in-sampling error: 0.004741831732706178
# 49 19.53107820423516
# Current relative in-sampling error: 0.004443819206767964
# 50 18.310222647614957
# Current relative in-sampling error: 0.00416604338126224
# 51 17.17165434371324
# Current relative in-sampling error: 0.003906990007752193
# 52 16.10927691658983
# Current relative in-sampling error: 0.003665272004981408
# 53 15.117499588335374
# Current relative in-sampling error: 0.0034396173281608274
# 54 14.191189653025685
# Current relative in-sampling error: 0.0032288581555793266
# 55 13.325630029542298
# Current relative in-sampling error: 0.003031921230786088
# 56 12.516481279897052
# Current relative in-sampling error: 0.0028478192207892143
# 57 11.759747562467945
# Current relative in-sampling error: 0.002675642969547171
# 58 11.05174606001573
# Current relative in-sampling error: 0.0025145545420616118
# 59 10.38907948246467
# Current relative in-sampling error: 0.002363780968057589
# 60 9.768611295882922
# Current relative in-sampling error: 0.002222608605943829
# 61 9.187443373237354
# Current relative in-sampling error: 0.002090378057788541
# 62 8.642895800466697
# Current relative in-sampling error: 0.0019664795746852175
# 63 8.132488604150208
# Current relative in-sampling error: 0.0018503488993304913
# 64 7.653925195340377
# Current relative in-sampling error: 0.0017414634990731554
# 65 7.205077348647985
# Current relative in-sampling error: 0.0016393391482723081
# 66 6.783971556926586
# Current relative in-sampling error: 0.001543526823639508
# 67 6.388776620441079
# Current relative in-sampling error: 0.0014536098804575938
# 68 6.017792345523909
# Current relative in-sampling error: 0.0013692014812362787
# 69 5.669439241837201
# Current relative in-sampling error: 0.0012899422515761081
# 70 5.342249119700052
# Current relative in-sampling error: 0.0012154981408202291
# 71 5.034856499763635
# Current relative in-sampling error: 0.001145558467536039
# 72 4.745990756829267
# Current relative in-sampling error: 0.0010798341320331125
# 73 4.474468927979588
# Current relative in-sampling error: 0.0010180559800293321
# 74 4.219189122571139
# Current relative in-sampling error: 0.000959973303255857
# 75 3.979124478164713
# Current relative in-sampling error: 0.000905352464276887
# 76 3.753317612226903
# Current relative in-sampling error: 0.0008539756341100339
# 77 3.5408755245641053
# Current relative in-sampling error: 0.0008056396323998409
# 78 3.3409649099713437
# Current relative in-sampling error: 0.0007601548609256543
# 79 3.152807844623935
# Current relative in-sampling error: 0.0007173443221455372
# 80 2.9756778133222306
# Current relative in-sampling error: 0.0006770427152929651
# 81 2.8088960479034153
# Current relative in-sampling error: 0.0006390956032719765
# 82 2.651828149992692
# Current relative in-sampling error: 0.0006033586442467963
# 83 2.5038809738151513
# Current relative in-sampling error: 0.0005696968824019088
# 84 2.3644997470818687
# Current relative in-sampling error: 0.0005379840928700983
# 85 2.233165410009912
# Current relative in-sampling error: 0.0005081021762915274
# 86 2.1093921543752967
# Current relative in-sampling error: 0.00047994059888542
# 87 1.992725146149414
# Current relative in-sampling error: 0.0004533958742916742
# 88 1.8827384167601648
# Current relative in-sampling error: 0.000428371083778903
# 89 1.779032909351188
# Current relative in-sampling error: 0.00040477543171850135
# 90 1.6812346676266554
# Current relative in-sampling error: 0.00038252383350057114
# 91 1.5889931559560881
# Current relative in-sampling error: 0.00036153653331485514
# 92 1.5019797003946462
# Current relative in-sampling error: 0.0003417387494430288
# 93 1.419886041175313
# Current relative in-sampling error: 0.0003230603449136961
# 94 1.3424229880259282
# Current relative in-sampling error: 0.00030543552155266526
# 95 1.2693191703994764
# Current relative in-sampling error: 0.0002888025356284143
# 96 1.2003198753739623
# Current relative in-sampling error: 0.000273103433444627
# 97 1.1351859665741937
# Current relative in-sampling error: 0.000258283805367283
# 98 1.0736928780170976
# Current relative in-sampling error: 0.0002442925568987652
# 99 1.015629677288638
# Current relative in-sampling error: 0.00023108169552667757
# 100 0.9607981929021823
# Current relative in-sampling error: 0.00021860613217558242
# 101 0.9090122011113074
# Current relative in-sampling error: 0.00020682349618614092
# 102 0.8600966678264799
# Current relative in-sampling error: 0.0001956939628317929
# 103 0.8138870416248368
# Current relative in-sampling error: 0.00018518009246042236
# 104 0.770228594165397
# Current relative in-sampling error: 0.00017524668042196874
# 105 0.7289758046007525
# Current relative in-sampling error: 0.00016586061700636206
# 106 0.6899917848511664
# Current relative in-sampling error: 0.0001569907566786989
# 107 0.6531477428373668
# Current relative in-sampling error: 0.00014860779595099132
# 108 0.6183224809987418
# Current relative in-sampling error: 0.00014068415928224627
# 109 0.585401927621639
# Current relative in-sampling error: 0.00013319389244368144
# 110 0.5542786986896017
# Current relative in-sampling error: 0.00012611256282846165
# 111 0.5248516881424761
# Current relative in-sampling error: 0.0001194171662251792
# 112 0.4970256845824752
# Current relative in-sampling error: 0.00011308603960869203
# 113 0.47071101261482934
# Current relative in-sampling error: 0.00010709877953596003
# 114 0.4458231971423694
# Current relative in-sampling error: 0.00010143616576448723
# MAX ITER STOP
# Total runtime: 34.98422336578369

# %%
plot_metrics(in_sampling_err_list, rank_arr)

# %%
# Parameters for matrix generation
n = 1000    # Matrix dimensions
r = 100      # Rank
m = .57*n*n  # Cardinality
p = m/(n*n)

# Generate a random low-rank matrix
M= random_matrix_generation(n,n,r)

# Calculate matrix characteristics
M_nuc = norm(M, 'nuc')
M_fro = norm(M, 'fro')
M_rank = matrix_rank(M)
M_shape = M.shape
print(p)

# Parameters for Singular Value Thresholding (SVT)
step_size = 1.2/p
tolerance = 1e-7
# Out:
# 0.57

# %%
M_sampled, coords, coords_TF, M_sampled_nans = sample_from_matrix_ratio(M,ratio_to_keep=p, seed=42)

# %%
start_time = time.time()
# Run the SVT algorithm
X_opt, em_sampled_arr, rank_arr, in_sampling_err_list = svt_algorithm(M_sampled, step_size, tolerance, tau=5*(n), max_iter=129)

run_time = time.time() - start_time
print('Total runtime:',run_time)
# Out:
# 5442.997187268785
# 2 7397.905267714553
# Current relative in-sampling error: 0.9812493335319991
# 3 5074.343268676663
# Current relative in-sampling error: 0.6730548405683752
# 4 3327.7697334522272
# Current relative in-sampling error: 0.4413914094505204
# 5 2195.04483245213
# Current relative in-sampling error: 0.29114812923008876
# 6 1586.1859926901234
# Current relative in-sampling error: 0.21038981872037552
# 7 1329.6628308211575
# Current relative in-sampling error: 0.1763648924053612
# 8 1158.8095273951851
# Current relative in-sampling error: 0.15370311396246583
# 9 1019.5857468748192
# Current relative in-sampling error: 0.1352366377230886
# 10 902.9059134926956
# Current relative in-sampling error: 0.11976036375098303
# 11 804.1561194514876
# Current relative in-sampling error: 0.10666230881748259
# 12 719.8609480875751
# Current relative in-sampling error: 0.09548149780037181
# 13 647.3505523458399
# Current relative in-sampling error: 0.0858638053697549
# 14 584.5228858134715
# Current relative in-sampling error: 0.0775304185958928
# 15 529.7233134791584
# Current relative in-sampling error: 0.07026186866385302
# 16 481.6360261008552
# Current relative in-sampling error: 0.06388362820472657
# 17 439.20713248290866
# Current relative in-sampling error: 0.058255910346969794
# 18 401.58466399553555
# Current relative in-sampling error: 0.0532657109874059
# 19 368.07392022465535
# Current relative in-sampling error: 0.048820885891464084
# 20 338.1035340001178
# Current relative in-sampling error: 0.0448456495989873
# 21 311.1997585671933
# Current relative in-sampling error: 0.04127716490531843
# 22 286.9667843808944
# Current relative in-sampling error: 0.0380629321043691
# 23 265.07156965850993
# Current relative in-sampling error: 0.03515877693119572
# 24 245.2320420309484
# Current relative in-sampling error: 0.03252728564310187
# 25 227.2078436776221
# Current relative in-sampling error: 0.030136577465364713
# 26 210.79300842307785
# Current relative in-sampling error: 0.027959333290063847
# 27 195.81011958746194
# Current relative in-sampling error: 0.0259720207803331
# 28 182.1056122888981
# Current relative in-sampling error: 0.024154271273349407
# 29 169.54596785680758
# Current relative in-sampling error: 0.022488375011853343
# 30 158.01460933273046
# Current relative in-sampling error: 0.02095886936707982
# 31 147.40935226598768
# Current relative in-sampling error: 0.01955220071533433
# 32 137.64029859877752
# Current relative in-sampling error: 0.018256445085423473
# 33 128.62808659314533
# Current relative in-sampling error: 0.017061076031054976
# 34 120.3024287469693
# Current relative in-sampling error: 0.015956770701757415
# 35 112.60088410488608
# Current relative in-sampling error: 0.014935247003665275
# 36 105.46782246213873
# Current relative in-sampling error: 0.013989126212752416
# 37 98.85354653312321
# Current relative in-sampling error: 0.013111816540314791
# 38 92.71354483151555
# Current relative in-sampling error: 0.01229741403588138
# 39 87.00785324158225
# Current relative in-sampling error: 0.011540617906794046
# 40 81.70050738913648
# Current relative in-sampling error: 0.010836657881344152
# 41 76.75907119866392
# Current relative in-sampling error: 0.010181231677151889
# 42 72.15422964112173
# Current relative in-sampling error: 0.00957045098371992
# 43 67.85943577932125
# Current relative in-sampling error: 0.009000794646953799
# 44 63.85060391520214
# Current relative in-sampling error: 0.008469067968582322
# 45 60.105842020540116
# Current relative in-sampling error: 0.00797236721608562
# 46 56.60521775548278
# Current relative in-sampling error: 0.007508048587672764
# 47 53.330553298883636
# Current relative in-sampling error: 0.007073700998821913
# 48 50.265244970782824
# Current relative in-sampling error: 0.006667122157221225
# 49 47.394104252079224
# Current relative in-sampling error: 0.006286297475807746
# 50 44.703217324413735
# Current relative in-sampling error: 0.005929381442305003
# 51 42.179820684370135
# Current relative in-sampling error: 0.005594681120838923
# 52 39.812190746173805
# Current relative in-sampling error: 0.00528064150897143
# 53 37.58954564884203
# Current relative in-sampling error: 0.004985832513517945
# 54 35.501957737523604
# Current relative in-sampling error: 0.004708937342176627
# 55 33.5402754028041
# Current relative in-sampling error: 0.004448742136387019
# 56 31.696053142890097
# Current relative in-sampling error: 0.004204126694861563
# 57 29.961488867276504
# Current relative in-sampling error: 0.003974056157618787
# 58 28.329367591277535
# Current relative in-sampling error: 0.0037575735376930326
# 59 26.793010782421657
# Current relative in-sampling error: 0.0035537930025006824
# 60 25.346230715172922
# Current relative in-sampling error: 0.003361893819504821
# 61 23.983289272331117
# Current relative in-sampling error: 0.0031811148916820776
# 62 22.698860701877418
# Current relative in-sampling error: 0.0030107498176350413
# 63 21.487997898698463
# Current relative in-sampling error: 0.0028501424192403473
# 64 20.34610183304881
# Current relative in-sampling error: 0.0026986826866763902
# 65 19.268893792979235
# Current relative in-sampling error: 0.002555803096692113
# 66 18.252390147331983
# Current relative in-sampling error: 0.0024209752652007864
# 67 17.292879370135257
# Current relative in-sampling error: 0.002293706899823093
# 68 16.386901097046724
# Current relative in-sampling error: 0.0021735390219587646
# 69 15.531227010525138
# Current relative in-sampling error: 0.002060043431418539
# 70 14.722843373186718
# Current relative in-sampling error: 0.0019528203896693778
# 71 13.958935048742951
# Current relative in-sampling error: 0.0018514965003907087
# 72 13.236870867435854
# Current relative in-sampling error: 0.0017557227683632096
# 73 12.554190208290938
# Current relative in-sampling error: 0.0016651728197548408
# 74 11.908590684073639
# Current relative in-sampling error: 0.0015795412686681494
# 75 11.297916826812276
# Current relative in-sampling error: 0.0014985422164015278
# 76 10.720149682332625
# Current relative in-sampling error: 0.0014219078712806841
# 77 10.173397231622644
# Current relative in-sampling error: 0.0013493872781598834
# 78 9.655885565153024
# Current relative in-sampling error: 0.0012807451477943473
# 79 9.16595074366074
# Current relative in-sampling error: 0.0012157607772642904
# 80 8.702031285462356
# Current relative in-sampling error: 0.0011542270535011144
# 81 8.262661226219667
# Current relative in-sampling error: 0.0010959495327429994
# 82 7.846463702279476
# Current relative in-sampling error: 0.0010407455894367416
# 83 7.452145013387414
# Current relative in-sampling error: 0.0009884436287231947
# 84 7.078489124723156
# Current relative in-sampling error: 0.0009388823571937771
# 85 6.724352571950492
# Current relative in-sampling error: 0.0008919101071023876
# 86 6.388659736314176
# Current relative in-sampling error: 0.0008473842096598859
# 87 6.070398459826559
# Current relative in-sampling error: 0.0008051704134376756
# 88 5.768615973285139
# Current relative in-sampling error: 0.0007651423442648083
# 89 5.482415112292413
# Current relative in-sampling error: 0.0007271810033253676
# 90 5.21095079865303
# Current relative in-sampling error: 0.0006911743004551836
# 91 4.953426766483638
# Current relative in-sampling error: 0.0006570166198969471
# 92 4.709092514173904
# Current relative in-sampling error: 0.000624608416011953
# 93 4.477240464943414
# Current relative in-sampling error: 0.0005938558366597533
# 94 4.25720332020188
# Current relative in-sampling error: 0.0005646703721510119
# 95 4.048351591254198
# Current relative in-sampling error: 0.0005369685278558052
# 96 3.850091296083795
# Current relative in-sampling error: 0.0005106715187077122
# 97 3.661861809045754
# Current relative in-sampling error: 0.0004857049839896746
# 98 3.483133852293131
# Current relative in-sampling error: 0.00046199872091917893
# 99 3.3134076186652455
# Current relative in-sampling error: 0.0004394864356703966
# 100 3.1522110165830495
# Current relative in-sampling error: 0.00041810551057919947
# 101 2.9990980282542052
# Current relative in-sampling error: 0.0003977967863774383
# 102 2.8536471731702213
# Current relative in-sampling error: 0.0003785043583930353
# 103 2.7154600695048954
# Current relative in-sampling error: 0.00036017538573558894
# 104 2.584160086594916
# Current relative in-sampling error: 0.0003427599125630077
# 105 2.4593910822044798
# Current relative in-sampling error: 0.0003262107005937946
# 106 2.340816218754775
# Current relative in-sampling error: 0.0003104830720931372
# 107 2.2281168531409667
# Current relative in-sampling error: 0.0002955347626195567
# 108 2.120991495156438
# Current relative in-sampling error: 0.00028132578287154094
# 109 2.019154829916153
# Current relative in-sampling error: 0.0002678182890229448
# 110 1.9223368000113943
# Current relative in-sampling error: 0.00025497646098108953
# 111 1.830281743435353
# Current relative in-sampling error: 0.0002427663880422404
# 112 1.7427475836101713
# Current relative in-sampling error: 0.00023115596145775969
# 113 1.6595050681093757
# Current relative in-sampling error: 0.0002201147734591579
# 114 1.5803370529073701
# Current relative in-sampling error: 0.00020961402232180006
# 115 1.505037829221878
# Current relative in-sampling error: 0.0001996264230780898
# 116 1.433412490210848
# Current relative in-sampling error: 0.0001901261235169021
# 117 1.3652763349867758
# Current relative in-sampling error: 0.00018108862513275363
# 118 1.3004543075761983
# Current relative in-sampling error: 0.00017249070871005898
# 119 1.2387804686280885
# Current relative in-sampling error: 0.00016431036425116214
# 120 1.1800974978143588
# Current relative in-sampling error: 0.0001565267249753325
# 121 1.1242562250083703
# Current relative in-sampling error: 0.00014912000513484143
# 122 1.071115188464421
# Current relative in-sampling error: 0.0001420714414124164
# 123 1.0205402183254395
# Current relative in-sampling error: 0.00013536323767819803
# 124 0.9724040439118815
# Current relative in-sampling error: 0.00012897851290100771
# 125 0.9265859233387297
# Current relative in-sampling error: 0.00012290125202118798
# 126 0.8829712941051742
# Current relative in-sampling error: 0.00011711625960523443
# 127 0.8414514433929321
# Current relative in-sampling error: 0.00011160911611455792
# 128 0.8019231968864484
# Current relative in-sampling error: 0.00010636613663096712
# 129 0.7642886250084759
# Current relative in-sampling error: 0.00010137433189210608
# MAX ITER STOP
# Total runtime: 41.343475341796875

# %%
plot_metrics(in_sampling_err_list, rank_arr)
